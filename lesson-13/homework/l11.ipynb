# %%
class py_solution:
    def abc(self, sset):
        return self.subsetsRecur([], sorted(sset))    
    def subsetsRecur(self, current, sset):
        if sset:
            return self.subsetsRecur(current, sset[1:]) + self.subsetsRecur(current + [sset[0]], sset[1:])
        return [current]
for name in py_solution.__dict__:
    print(name)
# Out:
# __module__
# sub_sets
# subsetsRecur
# __dict__
# __weakref__
# __doc__

# %%
#6
def student_data(student_id, **kwargs):
    print(f'{student_id}')
    if 'student_name' in kwargs:
        print(f"{kwargs['student_name']}")
        if 'student_class' in kwargs:
            print(f"{kwargs['student_class']}")
        #print(1)

student_data('123', student_name='Melony', student_class = 'A')
# Out:
# 123
# Melony
# A

# %%
class Student:
    student_name = 'Johnny'
    marks = 75
print(getattr(Student, 'student_name'))
print(getattr(Student, 'marks'))
setattr(Student, 'student_name', 'Alice')
setattr(Student, 'marks', 82)
print(getattr(Student, 'student_name'))
print(getattr(Student, 'marks'))
# Out:
# Johnny
# 75
# Alice
# 82

# %%
print(getattr(Student, 'student_name'))
# Out:
# Alice

# %%
class Student:
    student_id = 'abc'
    student_name = 'Raj'
print(getattr(Student, 'student_id'))
print(getattr(Student, 'student_name'))

Student.student_class = 'A'
print(getattr(Student, 'student_class'))

del Student.student_name
for i, j in Student.__dict__.items():
    print(j)
# Out:
# abc
# Raj
# A
# __main__
# abc
# <attribute '__dict__' of 'Student' objects>
# <attribute '__weakref__' of 'Student' objects>
# None
# A

# %%
class py_solution:
    def int_to_Roman(self, num):
        val = [
            1000, 900, 500, 400,
            100, 90, 50, 40,
            10, 9, 5, 4,
            1
            ]
        syb = [
            "M", "CM", "D", "CD",
            "C", "XC", "L", "XL",
            "X", "IX", "V", "IV",
            "I"
            ]
        rim = ''
        qoldiq = 0
        while num>0:
            for a in range(0, 12):
                if val[a] > num and val[a+1] <= num:
                    print(val[a+1])
                    rim += syb[a+1]
                    num = num-val[a+1]
            return rim


print(py_solution().int_to_Roman(90))
# Out:
# 90
# XC

# %%
5//2
# Out:
# 2

# %%
#nums = [-25, -10, -7, -3, 2, 4, 8, 10]

class threenumbers:
    def sumthree(self, nums):
        nums, added, final = sorted(nums), [], 0
        for a in nums:
            for b in nums:
                if b != a:
                    for c in nums.remove(b):
                        if c!= a and c!=b:
                            added = [a, b, c]
                            return added


print(threenumbers().sumthree([-25, -10, -7, -3, 2, 4, 8, 10]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 15
#      11                             added = [a, b, c]
#      12                             return added
# ---> 15 print(threenumbers().sumthree([-25, -10, -7, -3, 2, 4, 8, 10]))
#
# Cell In[10], line 9, in threenumbers.sumthree(self, nums)
#       7 for b in nums:
#       8     if b != a:
# ----> 9         for c in nums.remove(b):
#      10             if c!= a and c!=b:
#      11                 added = [a, b, c]
#
# TypeError: 'NoneType' object is not iterable

# %% [markdown]
# ## Student Information

# %%
#Students Information
#1.Add a student
#2.List all students
# 3.Enroll a student to the Course
# 4.Display courses
# 5.Exit

# %%
class Student:
    def __init__(self, id, name):
        self.id = id
        self.name = name
        self.courses_students = []
    
    def __str__(self) -> str:
        return f'Student Id: {self.id}, Name: {self.name}'
    
    def enroll_course(self, course):
        self.courses_students.append(course)

    def display_courses(self):
        print(f'{self.name}\'s courses are following:')
        for course in self.courses_students:
            print(course)

Jack = Student(1, 'Jackson')  
Jack.enroll_course('Geography')         
Jack.display_courses()
Jack.__str__()
# Out:
# Jackson's courses are following:
# Geography
# 'Student Id: 1, Name: Jackson'

# %%
class Course:
    def __init__(self, course_code, course_name):
        self.course_code = course_code
        self.course_name = course_name

    def __str__(self) -> str:
        return f'Course Code: {self.course_code}, Course Name: {self.course_name}'

# %%
class StudentList:
    def __init__(self):
        self.students = []

    def add_student(self, student):
        self.students.append(student)

    def list_students(self):
        print("List of students:")
        for student in self.students:
            print(student)

    def search_student(self, id):
        for student in self.students:
            if student.id == id:
                return student

# %%
import random
random = creator_name

# %%
def print_menu():
    print("Welcome to Students Information program")
    print("1.Add a student")
    print("2.List all students")
    print("3.Enroll a student in a course")
    print("4.Display courses for a student")
    print("5.Exit")

def main():
    studentlist = StudentList()

    while True:
        print_menu()
        choice = input("Enter your choice 1-5")

        if choice == "1":
            id = input("Enter Student ID: ")
            name = input("Enter Student Name: ")
            student = Student(id, name)
            studentlist.add_student(student)
            print('Student {name} have been added successfully')

        elif choice == "2":
            studentlist.list_students()

        elif choice == "3":
            id = input("Enter Student ID: ")
            student = studentlist.search_student(id)
            if student:
                course_code = input("Enter course code: ")
                course_name = input("Enter course name: ")
                course = Course(course_code, course_name)
                student.enroll_course(course)
                print(f"Student {student.name} enrolled in {course_name} successfully")
            else: 
                print(f'Student with ID{id} not found')

        elif choice == "4":
            id = input("Enter student ID: ")
            student = studentlist.search_student(id)
            if student:
                student.display_courses()
            else:
                print(f'Student with ID {id} not found')

        elif choice == "5":
            print(f'Exiting the program')
            break
            
        else:
            print('Please enter numbers between 1 and 5')

main()
# Out:
# Welcome to Students Information program
# 1.Add a student
# 2.List all students
# 3.Enroll a student in a course
# 4.Display courses for a student
# 5.Exit
# Student {name} have been added successfully
# Welcome to Students Information program
# 1.Add a student
# 2.List all students
# 3.Enroll a student in a course
# 4.Display courses for a student
# 5.Exit
# List of students:
# Student Id: 5, Name: Nani
# Welcome to Students Information program
# 1.Add a student
# 2.List all students
# 3.Enroll a student in a course
# 4.Display courses for a student
# 5.Exit
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 53
#      50         else:
#      51             print('Please enter numbers between 1 and 5')
# ---> 53 main()
#
# Cell In[30], line 28, in main()
#      26 elif choice == "3":
#      27     id = input("Enter Student ID: ")
# ---> 28     student = studentlist.search_student(id)
#      29     if student:
#      30         course_code = input("Enter course code: ")
#
# Cell In[29], line 15, in StudentList.search_student(self, id)
#      13 def search_student(self, id):
#      14     for student in self.students:
# ---> 15         if student[0] == id:
#      16             return student
#
# TypeError: 'Student' object is not subscriptable

# %%
class Student:
    def __init__(self, id, name):
        self.id = id
        self.name = name
        self.courses_students = []

    def __str__(self) -> str:
        return f'Student Id: {self.id}, Name: {self.name}'

    def enroll_course(self, course):
        self.courses_students.append(course)

    def display_courses(self):
        if self.courses_students:
            print(f"{self.name}'s courses are:")
            for course in self.courses_students:
                print(course)  # Use the Course object's __str__ method here
        else:
            print(f"{self.name} is not enrolled in any courses.")

class Course:
    def __init__(self, course_code, course_name):
        self.course_code = course_code
        self.course_name = course_name

    def __str__(self) -> str:
        return f'Course Code: {self.course_code}, Course Name: {self.course_name}'

class StudentList:
    def __init__(self):
        self.students = []

    def add_student(self, student):
        self.students.append(student)

    def list_students(self):
        print("List of students:")
        for student in self.students:
            print(student)

    def search_student(self, id):
        for student in self.students:
            if student.id == id:
                return student
        return None

def print_menu():
    print("Welcome to Students Information program")
    print("1. Add a student")
    print("2. List all students")
    print("3. Enroll a student in a course")
    print("4. Display courses for a student")
    print("5. Exit")

#clear()

def main():
    studentlist = StudentList()

    while True:
        print_menu()
        choice = input("Enter your choice (1-5): ")

        if choice == "1":
            id = input("Enter Student ID: ")
            name = input("Enter Student Name: ")
            student = Student(id, name)
            studentlist.add_student(student)
            print(f"Student {name} has been added successfully.")

        elif choice == "2":
            studentlist.list_students()

        elif choice == "3":
            id = input("Enter Student ID: ")
            student = studentlist.search_student(id)
            if student:
                course_code = input("Enter course code: ")
                course_name = input("Enter course name: ")
                course = Course(course_code, course_name)
                student.enroll_course(course)
                print(f"Student {student.name} enrolled in {course_name} successfully.")
            else:
                print(f"Student with ID {id} not found.")

        elif choice == "4":
            id = input("Enter Student ID: ")
            student = studentlist.search_student(id)
            if student:
                student.display_courses()
            else:
                print(f"Student with ID {id} not found.")

        elif choice == "5":
            print("Exiting the program.")
            break

        else:
            print("Please enter a number between 1 and 5.")

main()
# Out:
# Welcome to Students Information program
# 1. Add a student
# 2. List all students
# 3. Enroll a student in a course
# 4. Display courses for a student
# 5. Exit
# Student Zanetti has been added successfully.
# Welcome to Students Information program
# 1. Add a student
# 2. List all students
# 3. Enroll a student in a course
# 4. Display courses for a student
# 5. Exit
# List of students:
# Student Id: 4, Name: Zanetti
# Welcome to Students Information program
# 1. Add a student
# 2. List all students
# 3. Enroll a student in a course
# 4. Display courses for a student
# 5. Exit
# Student Zanetti enrolled in Math successfully.
# Welcome to Students Information program
# 1. Add a student
# 2. List all students
# 3. Enroll a student in a course
# 4. Display courses for a student
# 5. Exit
# Zanetti's courses are:
# Course Code: 1, Course Name: Math
# Welcome to Students Information program
# 1. Add a student
# 2. List all students
# 3. Enroll a student in a course
# 4. Display courses for a student
# 5. Exit
# Exiting the program.

# %%
data = "apple,banana,cherry"
result = data.split(",")
print(result)  # Output: ['apple', 'banana', 'cherry']
# Out:
# <built-in method split of str object at 0x106a30d70>

# %%
a = 'jfknkqgj.e3j3e'
b =  'fjifiqrgifi'
print(f'{a} {b}')
# Out:
# jfknkqgj.e3j3e fjifiqrgifi

# %%
class Task:
    def __init__(self, title, description, date, status):
        self.task_title = title
        self.description = description
        self.due_date = date
        self.status = status
        
        def __str__(self):
            return f'Title: {self.title}, DesCription: {self.description}, Date: {self.date}, Status: {self.status}'

# %%
#• Create a ToDoList class that manages a list of tasks.
#• Include methods to add a task, mark a task as complete, list all tasks, and display
# incomplete tasks

class ToDoList:
    def __init__(self):
        self.tasks = []

        def add_task(self, task):
            self.tasks.append(task)

            def mark_task_complete(self,title):
                for task in self.tasks:
                    if task.title == title:
                        task.status = 'Completed'
                        return True
                    return False
                
                def list_all_tasks(self):
                    for task in self.tasks:
                        print(task)

                        def display(self):
                            for task in self.tasks:
                                if task.status == 'Incopmplete':
                                    print (task)
                                    print("There are no incomplete tasks")

# %%
#• Include options to add tasks, mark tasks as complete, list all tasks, and display only
#incomplete tasks.

class Main_Program:
    def __init__(self):
        self.tasks = []
        
        def add_task(self, tasks):
            self.tasks.append(task)

            def mark_tasks_as_complete(self, title):
                for task in self.tasks:
                    if tasks.title == title:
                        tasks.status == 'Complete'
                        return True
                        return False
                    
                    def list_all_tasks(self):
                        for task
                        def

# %%
#• Create a Post class with attributes like title, content, and author.

class Post:
    def __init__(self, title, content, author):
        self.title = title 
        self.content = content
        self.author = author
        
        def __str__(self):
            return f'Title: {self.title}, Content: {self.content}, Author: {self.author}'

# %%
# Create a Blog class that manages a list of posts.
# Include methods to add a post, list all posts, and display posts by a specific author.
class Blog:
    def __init__(self):
        self.posts = []

        def add_post(self,post):
            self.posts.append(post)

            def list_all_posts(self):
                for post in self.posts:
                    print(post)

                    def display_posts_by_author(self, author):
                        for post in self.posts:
                            if post.author == author:
                                print(post)
                                print('There are no post authors')

# %%
import math 
a = 25
print(math.sqrt(a))
# Out:
# 5.0

# %%
dir(math)
# Out:
# ['__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'cbrt',
#  'ceil',
#  'comb',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'dist',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'exp2',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fma',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'isqrt',
#  'lcm',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'nan',
#  'nextafter',
#  'perm',
#  'pi',
#  'pow',
#  'prod',
#  'radians',
#  'remainder',
#  'sin',
#  'sinh',
#  'sqrt',
#  'sumprod',
#  'tan',
#  'tanh',
#  'tau',
#  'trunc',
#  'ulp']

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 import speech_recognition as sr
#       2 r = sr.Recognizer()
#       3 with sr.Microphone() as source:
#
# ModuleNotFoundError: No module named 'speech_recognition'

# %%
# Berilgan sonlarni ro’yxatdan toping va faqat toq sonlar ro’yxatini qaytaring.
def find_odd_numbers(numbers):
    return [son for son in numbers if son % 2 != 0]

numbers = list(map(int, input("Sonlarni probel bilan kiriting: ").split()))
print("Toq sonlar:", find_odd_numbers(numbers))
# Out:
# Juft sonlar: []
# Toq sonlar: []

# %%
# Program to find and display all even numbers in a list entered by the user
numbers = input("Enter a list of numbers separated by commas: ")  
even_numbers = []

for num in numbers:  # Mistake 2: Iterating over the string directly
    if num % 2 <= 0:
    else: # Mistake 1: Missing the else block
    
        even_numbers.append(num)

print("The even numbers are: " +  even_numbers)  
print("The total number of even numbers is", len(even_numbers))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[53], line 6
#       3 even_numbers = []
#       5 for num in numbers:  # Mistake 2: Iterating over the string directly
# ----> 6     if num % 2 <= 0:
#       7         even_numbers.append(num)
#       9 print("The even numbers are: " + even_numbers)
#
# TypeError: not all arguments converted during string formatting

# %%
numbers = input("Enter a list of numbers separated by commas: ")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 numbers = input(int("Enter a list of numbers separated by commas: "))
#
# ValueError: invalid literal for int() with base 10: 'Enter a list of numbers separated by commas: '

# %%
even_numbers = []
if even_numbers != 0:
    for num in numbers:
        if num % 2 == 0:
            even_numbers.append(num)
            print("The even numbers are: " + even_numbers)

# %%
 len({'a': 1, 'b': 2, 'c': 3})
# Out:
# 3

# %%
MyClass: x = 10; y = 20; 
print(MyClass().x + MyClass().y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 MyClass: x = 10; y = 20;
#       2 print(MyClass().x + MyClass().y)
#
# NameError: name 'x' is not defined

# %%
False: print("Hello")
# Out:
#   Cell In[5], line 1
#     False: print("Hello")
#     ^
# SyntaxError: illegal target for annotation

# %%
{'a': 1, 'b': 2}.get('c', 3)
# Out:
# 3

# %%
print("Hello" + "World")
# Out:
# HelloWorld

# %%
MyClass: x = 5; print(MyClass().x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 MyClass: x = 5; print(MyClass().x)
#
# NameError: name 'x' is not defined

# %%
def add(a, b):
     return a + b; 
print(add(2, 3))
# Out:
# 5

# %%
divmod(9, 2)

# %%
from module import function
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from module import function
#
# ModuleNotFoundError: No module named 'module'

# %%
import module.function
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import module.function
#
# ModuleNotFoundError: No module named 'module'

# %%
include module.function
# Out:
#   Cell In[6], line 1
#     include module.function
#             ^
# SyntaxError: invalid syntax

# %%
using module.function
# Out:
#   Cell In[7], line 1
#     using module.function
#           ^
# SyntaxError: invalid syntax
